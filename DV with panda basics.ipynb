# %% [markdown]
# <a href="https://colab.research.google.com/github/21pa5a0505/Compiler-Design-Lab/blob/main/DV%20with%20panda%20basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %%
plt.style.use("fivethirtyeight")

# %%
data=pd.Series(np.random.randn(1000).cumsum())

# %%
data.plot()
# Out:
# <Axes: >

# %%
df1 = pd.DataFrame(np.random.randn(100, 4),columns=list('ABCD'))

# %%
df1 = df1.cumsum()

# %%
df1.plot()
# Out:
# <Axes: >
